# %% [markdown]
# # Validation without pydantic

# %%
# Student class 
# name, age, gender 

# instantiate instance from Student

class Student:
    def __init__(self, name, age, gender):
        self.name = name
        self.age = age 
        self.gender = gender
